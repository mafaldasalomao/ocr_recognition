# %% [markdown]
# <a href="https://colab.research.google.com/github/mafaldasalomao/ocr_recognition/blob/main/OCR_com_EasyOCR_e_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reconhecimento de texto com EasyOCR
#
# - Mantida por por [Jaided AI](https://jaided.ai/), uma empresa especializada em serviços de OCR
# - Repositório oficial: https://github.com/JaidedAI/EasyOCR

# %% [markdown]
# # Instalação

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: easyocr in /usr/local/lib/python3.9/dist-packages (1.6.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from easyocr) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from easyocr) (6.0)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.9/dist-packages (from easyocr) (0.4.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.9/dist-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.9/dist-packages (from easyocr) (0.15.1+cu118)
# Requirement already satisfied: ninja in /usr/local/lib/python3.9/dist-packages (from easyocr) (1.11.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from easyocr) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from easyocr) (1.10.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from easyocr) (8.4.0)
# Collecting opencv-python-headless<=4.5.4.60
#   Using cached opencv_python_headless-4.5.4.60-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.6 MB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.9/dist-packages (from easyocr) (2.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from easyocr) (2.0.0+cu118)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.5->easyocr) (2.27.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->easyocr) (3.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->easyocr) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->easyocr) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->easyocr) (3.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->easyocr) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->easyocr) (3.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image->easyocr) (23.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->easyocr) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->easyocr) (2023.3.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->easyocr) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5->easyocr) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5->easyocr) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.5->easyocr) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->easyocr) (1.3.0)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.5.4.60

# %%
# Código necessário após atualização do opencv-python-headless no Colab para a versão 4.5.5.62, que não suporta o "_registerMatType".
# !pip uninstall opencv-python-headless
# !pip install opencv-python-headless==4.3.0.38
# Out:
# WARNING: Skipping opencv-python-headless as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless==4.3.0.38
#   Downloading opencv-python-headless-4.3.0.38.tar.gz (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 10.2 MB/s eta 0:00:00

# %%
from easyocr import Reader
import cv2
from google.colab.patches import cv2_imshow
from PIL import ImageFont, ImageDraw, Image
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-6880ef72b31f> in <cell line: 1>()
# ----> 1 from easyocr import Reader
#       2 import cv2
#       3 from google.colab.patches import cv2_imshow
#       4 from PIL import ImageFont, ImageDraw, Image
#       5 import numpy as np
#
# /usr/local/lib/python3.9/dist-packages/easyocr/__init__.py in <module>
# ----> 1 from .easyocr import Reader
#       2
#       3 __version__ = '1.6.2'
#
# /usr/local/lib/python3.9/dist-packages/easyocr/easyocr.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .recognition import get_recognizer, get_text
#       4 from .utils import group_text_box, get_image_list, calculate_md5, get_paragraph,\
#       5                    download_and_unzip, printProgressBar, diff, reformat_input,\
#
# /usr/local/lib/python3.9/dist-packages/easyocr/recognition.py in <module>
#       8 from collections import OrderedDict
#       9 import importlib
# ---> 10 from .utils import CTCLabelConverter
#      11 import math
#      12
#
# /usr/local/lib/python3.9/dist-packages/easyocr/utils.py in <module>
#       5 import numpy as np
#       6 import math
# ----> 7 import cv2
#       8 from PIL import Image, JpegImagePlugin
#       9 from scipy import ndimage
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_import_hooks/_cv2.py in load_module(self, name)
#      75     previously_loaded = name in sys.modules
#      76
# ---> 77     module_info = imp.find_module(name, self.path)
#      78     cv_module = imp.load_module(name, *module_info)
#      79
#
# /usr/lib/python3.9/imp.py in find_module(name, path)
#     294         break  # Break out of outer loop when breaking out of inner loop.
#     295     else:
# --> 296         raise ImportError(_ERR_MSG.format(name), name=name)
#     297
#     298     encoding = None
#
# ImportError: No module named 'cv2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Configurações

# %%
lista_idiomas = 'en,pt'
idiomas = lista_idiomas.split(',')
print(idiomas)

# %%
gpu = True #@param {type: 'boolean'}

# %%
img = cv2.imread('caneca.jpg')
cv2_imshow(img)

# %%
original = img.copy()

# %% [markdown]
# # Reconhecimento (OCR)

# %%
reader = Reader(idiomas, gpu)
resultados = reader.readtext(img)

# %%
resultados

# %%
resultados[0][0]

# %% [markdown]
# # Escrevendo os resultados na imagem

# %% [markdown]
# ## Texto

# %%
fonte = '/content/calibri.ttf'

# %%
def escreve_texto(texto, x, y, img, fonte, cor=(50,50,255), tamanho = 22):
  fonte = ImageFont.truetype(fonte, tamanho)
  img_pil = Image.fromarray(img)
  draw = ImageDraw.Draw(img_pil)
  draw.text((x, y - tamanho), texto, font = fonte, fill = cor)
  img = np.array(img_pil)
  return img

# %% [markdown]
# ## Caixa delimitadora
#
# Cantos da bounding box:
# * **te** = topo esquerdo (superior esquerdo)
# * **td** = topo direito (superior direito)
# * **bd** = baixo direito (inferior direito)
# * **be** = baixo esquerdo (inferior esquerdo)

# %%
def coordenada_caixa(caixa):
  (te, td, bd, be) = caixa
  te = (int(te[0]), int(te[1]))
  td = (int(td[0]), int(td[1]))
  bd = (int(bd[0]), int(bd[1]))
  be = (int(be[0]), int(be[1]))
  return te, td, bd, be

# %%
coordenada_caixa(resultados[0][0])

# %%
def desenha_caixa(img, te, bd, cor_caixa=(200,255,0), espessura=2):
  cv2.rectangle(img, te, bd, cor_caixa, espessura)
  return img

# %%
img = original.copy()
for (caixa, texto, probabilidade) in resultados:
  #print(caixa, texto, probabilidade)
  te, td, bd, be = coordenada_caixa(caixa)
  img = desenha_caixa(img, te, bd)
  img = escreve_texto(texto, te[0], te[1], img, fonte)
cv2_imshow(img)

# %%
img = cv2.imread('/content/google-cloud.jpg')
reader = Reader(idiomas, gpu)
resultados = reader.readtext(img)

for (caixa, texto, probabilidade) in resultados:
  te, td, bd, be = coordenada_caixa(caixa)
  img = desenha_caixa(img, te, bd)
  img = escreve_texto(texto, te[0], te[1], img, fonte)
cv2_imshow(img)

# %% [markdown]
# # Outros idiomas
#
# - Outros idiomas [veja aqui](https://www.jaided.ai/easyocr/)

# %%
lista_idiomas = 'en,fr'
idiomas = lista_idiomas.split(',')
idiomas

# %%
img = cv2.imread('/content/frances.jpg')
reader = Reader(idiomas, gpu)
resultados = reader.readtext(img)
resultados

# %%
for (caixa, texto, probabilidade) in resultados:
  te, td, bd, be = coordenada_caixa(caixa)
  img = desenha_caixa(img, te, bd)
  img = escreve_texto(texto, te[0], te[1], img, fonte)
cv2_imshow(img)

# %%
lista_idiomas = 'en,ch_sim'
idiomas = lista_idiomas.split(',')
idiomas

# %%
fonte = '/content/simsun.ttc'

# %%
img = cv2.imread('/content/chines.jpg')
reader = Reader(idiomas, gpu)
resultados = reader.readtext(img)
resultados

# %%
for (caixa, texto, probabilidade) in resultados:
  te, td, bd, be = coordenada_caixa(caixa)
  img = desenha_caixa(img, te, bd)
  img = escreve_texto(texto, te[0], te[1], img, fonte)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x339 at 0x7F4621910250>

# %% [markdown]
# # Texto com fundo

# %%
def fundo_texto(texto, x, y, img, fonte, tamanho=32, cor_fundo=(200,255,0)):
  fundo = np.full((img.shape), (0,0,0), dtype=np.uint8)
  texto_fundo = escreve_texto(texto, x, y, fundo, fonte, tamanho=tamanho)
  texto_fundo = cv2.dilate(texto_fundo,(np.ones((3,5),np.uint8)))
  fx,fy,fw,fh = cv2.boundingRect(texto_fundo[:,:,2])
  cv2.rectangle(img, (fx, fy), (fx + fw, fy + fh), cor_fundo, -1) 
  return img

# %%
fonte = '/content/calibri.ttf'
lista_idiomas = 'en,pt'
idiomas = lista_idiomas.split(',')

# %%
img = cv2.imread('/content/placa-infos.jpg')
reader = Reader(idiomas, gpu)
resultados = reader.readtext(img)
resultados
# Out:
# [([[260, 164], [302, 164], [302, 196], [260, 196]], '310', 0.9998522330811639),
#  ([[344, 184], [368, 184], [368, 212], [344, 212]], 'i', 0.7931398468144835),
#  ([[134, 262], [180, 262], [180, 290], [134, 290]],
#   'Cine',
#   0.9994775056838989),
#  ([[304.07944680100655, 128.69533616120788],
#    [366.51745895966945, 117.36831363725129],
#    [370.92055319899345, 145.30466383879212],
#    [307.48254104033055, 155.6316863627487]],
#   'União',
#   0.9999735571992951),
#  ([[202.01488842937005, 155.701488842937],
#    [304.70640266490693, 133.705633508088],
#    [309.98511157062995, 157.298511157063],
#    [207.29359733509307, 180.294366491912]],
#   'Ferroviária',
#   0.9996482215261095),
#  ([[132.65739357167092, 171.12591485733674],
#    [208.5373938916925, 155.3994900067786],
#    [214.34260642832908, 182.87408514266326],
#    [138.4626061083075, 199.6005099932214]],
#   'Estação',
#   0.9999682347393094),
#  ([[183.7701175612585, 185.99310580513264],
#    [261.70640266490693, 174.705633508088],
#    [265.2298824387415, 199.00689419486736],
#    [187.29359733509307, 210.294366491912]],
#   'Fumaça',
#   0.6102963762095986),
#  ([[134.17086771745093, 197.6221280326862],
#    [189.52876662873277, 190.38589364123442],
#    [192.82913228254907, 215.3778719673138],
#    [137.47123337126723, 223.61410635876558]],
#   'Maria',
#   0.8060824150357994),
#  ([[241.42752122286237, 208.45651273371743],
#    [337.7201633356655, 191.73480775085324],
#    [341.57247877713763, 217.54348726628257],
#    [246.27983666433448, 234.26519224914676]],
#   'Turísticas',
#   0.9984297945704468),
#  ([[130.0, 235.0],
#    [245.7284234267574, 209.75272071919662],
#    [252.0, 235.0],
#    [135.2715765732426, 260.24727928080335]],
#   'Informações',
#   0.9946799534529847),
#  ([[232.60276070150212, 243.34524533285406],
#    [271.3564750166826, 241.14338332018946],
#    [272.3972392984979, 267.65475466714594],
#    [233.6435249833174, 270.85661667981054]],
#   'Luz',
#   0.9996672360515431),
#  ([[174.41000317999047, 253.45600508798475],
#    [236.58087460090252, 246.4705928290948],
#    [239.58999682000953, 274.54399491201525],
#    [177.41912539909748, 281.5294071709052]],
#   'Teatro;',
#   0.7550331422135224)]

# %%
cor_fonte = (0,0,0)
cor_fundo = (200,255,0)
cor_caixa = (200,255,0)
tamanho_fonte = 18

# %%
for (caixa, texto, probabilidade) in resultados:
  te, td, bd, be = coordenada_caixa(caixa)
  img = desenha_caixa(img, te, bd, cor_caixa)
  img = fundo_texto(texto, te[0], te[1], img, fonte, tamanho_fonte, cor_fundo)
  img = escreve_texto(texto, te[0], te[1], img, fonte, cor_fonte, tamanho_fonte)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=507x434 at 0x7F4620093290>
